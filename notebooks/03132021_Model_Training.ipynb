# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
#Set notebook preferences
pd.set_option('display.float_format', lambda x: '%.3f' % x)

plt.style.use('Solarize_Light2')

# %%
import yaml
path= r'/Users/ksharma/Documents/ML Engineer/Machine Learning/Projects/paysim_credit_fraud_analysis/'
config_name= 'config.yaml'

#read yaml file
with open(os.path.join(path, config_name)) as file:
    config = yaml.safe_load(file)
    
df= pd.read_csv(config['paths']['cleanedData'], dtype={'isFraud':'int', 'isFlaggedFraud':'int'})
df.drop('Unnamed: 0', axis= 1, inplace= True)

# %% [markdown]
# **Data Overview**

# %%
df
# Out:
#          step      type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1   PAYMENT    9839.640     170136.000      160296.360
# 1           1   PAYMENT    1864.280      21249.000       19384.720
# 2           1  TRANSFER     181.000        181.000           0.000
# 3           1  CASH_OUT     181.000        181.000           0.000
# 4           1   PAYMENT   11668.140      41554.000       29885.860
# ...       ...       ...         ...            ...             ...
# 6362615   743  CASH_OUT  339682.130     339682.130           0.000
# 6362616   743  TRANSFER 6311409.280    6311409.280           0.000
# 6362617   743  CASH_OUT 6311409.280    6311409.280           0.000
# 6362618   743  TRANSFER  850002.520     850002.520           0.000
# 6362619   743  CASH_OUT  850002.520     850002.520           0.000
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0                 0.000           0.000        0               0
# 1                 0.000           0.000        0               0
# 2                 0.000           0.000        1               0
# 3             21182.000           0.000        1               0
# 4                 0.000           0.000        0               0
# ...                 ...             ...      ...             ...
# 6362615           0.000      339682.130        1               0
# 6362616           0.000           0.000        1               0
# 6362617       68488.840     6379898.110        1               0
# 6362618           0.000           0.000        1               0
# 6362619     6510099.110     7360101.630        1               0
#
# [6362620 rows x 9 columns]

# %% [markdown]
# **Preprocessing**

# %%
#Copy original df & drop flags cols
temp= df.copy().drop('isFlaggedFraud', axis=1)

#Create dummies
dummies= pd.get_dummies(temp.iloc[:, :-1], drop_first=False)
dummies.loc[:,'isFraud']= temp.loc[:,'isFraud'].apply(lambda x: int(x))

dummies.head()
# Out:
#    step    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0     1  9839.640     170136.000      160296.360           0.000
# 1     1  1864.280      21249.000       19384.720           0.000
# 2     1   181.000        181.000           0.000           0.000
# 3     1   181.000        181.000           0.000       21182.000
# 4     1 11668.140      41554.000       29885.860           0.000
#
#    newbalanceDest  type_CASH_IN  type_CASH_OUT  type_DEBIT  type_PAYMENT  \
# 0           0.000             0              0           0             1
# 1           0.000             0              0           0             1
# 2           0.000             0              0           0             0
# 3           0.000             0              1           0             0
# 4           0.000             0              0           0             1
#
#    type_TRANSFER  isFraud
# 0              0        0
# 1              0        0
# 2              1        1
# 3              0        1
# 4              0        0

# %%
# #Split data
# X= dummies.iloc[:,:-1].values
# y= dummies.iloc[:,-1].values

# #Create training and test data
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 24, test_size=.1)


# #Sanity check
# for item in [X_train, X_test, y_train, y_test]:
#     print(item.shape)

# %%
#How to handle such few fraud cases

# %%
config['paths']['pyScripts']
# Out:
# '/Users/ksharma/Documents/ML Engineer/Machine Learning/Projects/paysim_credit_fraud_analysis/src'

# %%
os.chdir(config['paths']['pyScripts'])
from models.metrics import classification_metrics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   oldbalanceOrg   float64
#  4   newbalanceOrig  float64
#  5   oldbalanceDest  float64
#  6   newbalanceDest  float64
#  7   isFraud         int64
#  8   isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 436.9+ MB

# %%
classification_metrics(predictions=df['isFlaggedFraud'].values,
                      actual= df['isFraud'].values)
# Out:
# {'accuracy': 0.999, 'precision': 1.0, 'recall': 0.002, 'f1_score': 0.004}

# %%
#Evaluate previous model predictions

# %% [markdown]
# Save trained model for Deployment

# %%
path= r''
